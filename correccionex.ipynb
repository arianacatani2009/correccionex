# %%
pip install pysqlite3
# Out:
# ...
#   Using cached pysqlite3-0.5.1.tar.gz (40 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pysqlite3
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [12 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-311
#   creating build\lib.win-amd64-cpython-311\pysqlite3
#   copying pysqlite3\dbapi2.py -> build\lib.win-amd64-cpython-311\pysqlite3
#   copying pysqlite3\__init__.py -> build\lib.win-amd64-cpython-311\pysqlite3
#   running build_ext
#   Builds a C extension linking against libsqlite3 library
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
movies_df=pd.read_csv("imdb_movies.csv",index_col=1)

# %%
movies_df
# Out:
#                                                names  score
# date_x
# 03/02/2023                                 Creed III   73.0  \
# 12/15/2022                  Avatar: The Way of Water   78.0
# 04/05/2023               The Super Mario Bros. Movie   76.0
# 01/05/2023                                   Mummies   70.0
# 03/17/2023                                 Supercell   61.0
# ...                                              ...    ...
# 12/28/2016                        20th Century Women   73.0
# 08/24/1990   Delta Force 2: The Colombian Connection   54.0
# 12/21/1990                          The Russia House   61.0
# 07/11/1995          Darkman II: The Return of Durant   55.0
# 07/20/2020        The Swan Princess: A Royal Wedding   70.0
#
#                                                          genre
# date_x
# 03/02/2023                                       Drama, Action  \
# 12/15/2022                  Science Fiction, Adventure, Action
# ...

# %%
import sqlite3 
con = sqlite3.connect("database.db")

# %%
import sqlite3 
con = sqlite3.connect("database.db")
con=pd.read_csv("imdb_movies.csv", index_col=1)

# %%
import pandas as pd
csv_data = pd.read_csv("imdb_movies.csv", sep = ",")
csv_data.to_json("Ariana.json", orient = "records")

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install couchdb
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import couchdb

# %%
import couchdb

# %%
import json
couch = couchdb.Server('http://admin:admin@127.0.0.1:5984/')
db = couch.create ('ariana2')
with open("prueba.json") as jsonfile:
    for row in jsonfile:
        db_entry = json.load(row)
        db.save(db_entry)
# Out:
# ---------------------------------------------------------------------------
# PreconditionFailed                        Traceback (most recent call last)
# Cell In[40], line 3
#       1 import json
#       2 couch = couchdb.Server('http://admin:admin@127.0.0.1:5984/')
# ----> 3 db = couch.create ('ariana2')
#       4 with open("prueba.json") as jsonfile:
#       5     for row in jsonfile:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\couchdb\client.py:221, in Server.create(self, name)
#     213 def create(self, name):
#     214     """Create a new database with the given name.
#     215
#     216     :param name: the name of the database
#    (...)
#     219     :raise PreconditionFailed: if a database with that name already exists
#     220     """
# --> 221     self.resource.put_json(name)
#     222     return self[name]
#
# ...

# %%
import csv
import json
import couchdb


couch = couchdb.Server('http://admin:admin@127.0.0.1:5984/')
db_name = 'correccion1'


if db_name in couch:
    db = couch[db_name]
else:
    db = couch.create(db_name)


csv_file = 'imdb_movies.csv'


encoding = 'utf-8'  


with open(csv_file, 'r', encoding=encoding, errors='replace') as file:
    csv_data = csv.DictReader(file)
    
    for row in csv_data:
        
        json_data = json.dumps(row)
        
        db.save(json.loads(json_data))
